# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

df = pd.read_csv("fortune500.csv")
print(df.head())
# Out:
#    Rank       Company                                 Industry  \
# 0     1        Amazon          Internet Services and Retailing
# 1     2       Walmart                    General Merchandisers
# 2     3  UnitedHealth  Health Care: Insurance and Managed Care
# 3     4         Apple              Computers, Office Equipment
# 4     5      Alphabet          Internet Services and Retailing
#
#        Revenue ($)            City        State    Zip                Website  \
# 0  716,924,000,000         Seattle   Washington  98109             amazon.com
# 1  712,700,000,000     Bentonville     Arkansas  72716            walmart.com
# 2  447,600,000,000    Eden Prairie    Minnesota  55344  unitedhealthgroup.com
# 3  416,161,000,000       Cupertino   California  95014              apple.com
# 4  402,836,000,000   Mountain View   California  94043                abc.xyz
#
#    Employees              CEO
# 0  1,556,000     Andrew Jassy
# 1  2,100,000      John Furner
# 2    400,000  Stephen Hemsley
# 3    164,000     Timothy Cook
# 4    183,323    Sundar Pichai

# %%
print(df.columns)
# Out:
# Index(['Rank', 'Company', 'Industry', 'Revenue ($)', ' City ', 'State', 'Zip',
#        'Website', 'Employees', 'CEO'],
#       dtype='str')

# %%
print(df.describe())
# Out:
#              Rank           Zip
# count  500.000000    500.000000
# mean   250.500000  47829.520000
# std    144.481833  30638.259507
# min      1.000000   1104.000000
# 25%    125.750000  20004.500000
# 50%    250.500000  46236.000000
# 75%    375.250000  77002.000000
# max    500.000000  98390.000000

# %%
print(df.tail())
# Out:
#      Rank                Company                     Industry    Revenue ($)  \
# 495   496        Electronic Arts                Entertainment  7,290,000,000
# 496   497          Newell Brands  Home Equipment, Furnishings  7,260,000,000
# 497   498              Ingredion              Food Production  7,260,000,000
# 498   499                KeyCorp             Commercial Banks  7,200,000,000
# 499   500  QXO Building Products     Wholesalers: Diversified  5,500,000,000
#
#               City        State    Zip           Website Employees  \
# 495   Redwood City   California  94065            ea.com    13,700
# 496        Atlanta      Georgia  30328  newellbrands.com    23,700
# 497    Westchester     Illinois  60154     ingredion.com    11,200
# 498      Cleveland         Ohio  44114           key.com    16,753
# 499        Herndon     Virginia  20170           qxo.com     8,068
#
#                       CEO
# 495         Andrew Wilson
# 496  Christopher Peterson
# 497          James Zallie
# 498    Christopher Gorman
# 499        Julian Francis

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Rank         500 non-null    int64
#  1   Company      500 non-null    str
#  2   Industry     500 non-null    str
#  3   Revenue ($)  500 non-null    str
#  4    City        500 non-null    str
#  5   State        500 non-null    str
#  6   Zip          500 non-null    int64
#  7   Website      500 non-null    str
#  8   Employees    500 non-null    str
#  9   CEO          500 non-null    str
# dtypes: int64(2), str(8)
# memory usage: 39.2 KB
# None

# %%
print(df.shape)
# Out:
# (500, 10)

# %%
print(df['Rank'].value_counts())
# Out:
# Rank
# 1      1
# 2      1
# 3      1
# 4      1
# 5      1
#       ..
# 496    1
# 497    1
# 498    1
# 499    1
# 500    1
# Name: count, Length: 500, dtype: int64

# %%
print(df['Company'].value_counts())
# Out:
# Company
# Amazon                   1
# Walmart                  1
# UnitedHealth             1
# Apple                    1
# Alphabet                 1
#                         ..
# Electronic Arts          1
# Newell Brands            1
# Ingredion                1
# KeyCorp                  1
# QXO Building Products    1
# Name: count, Length: 500, dtype: int64

# %%
print(df['Industry'].value_counts())
# Out:
# Industry
# Utilities: Gas and Electric                       21
# Commercial Banks                                  20
# Insurance: Property and Casualty (Stock)          18
# Specialty Retailers: Other                        16
# Diversified Financials                            15
#                                                   ..
# Waste Management                                   2
# Advertising, Marketing                             2
# Scientific, Photographic and Control Equipment     1
# Trucking, Truck Leasing                            1
# Publishing, Printing                               1
# Name: count, Length: 67, dtype: int64

# %%
print(df['Revenue ($)'].value_counts())
# Out:
# Revenue ($)
# 8,770,000,000     4
# 15,010,000,000    3
# 10,500,000,000    3
# 7,500,000,000     3
# 37,650,000,000    2
#                  ..
# 7,410,000,000     1
# 7,350,000,000     1
# 7,290,000,000     1
# 7,200,000,000     1
# 5,500,000,000     1
# Name: count, Length: 465, dtype: int64

# %%
print(df['Revenue ($)'].dtype)
# Out:
# str

# %%
df['Revenue ($)'] = df['Revenue ($)'].str.replace(',','').astype(float)
print(df['Revenue ($)'].dtypes)
# Out:
# float64

# %%
print(df['Revenue ($)'].value_counts())
# Out:
# Revenue ($)
# 8.770000e+09    4
# 1.501000e+10    3
# 1.050000e+10    3
# 7.500000e+09    3
# 3.765000e+10    2
#                ..
# 7.410000e+09    1
# 7.350000e+09    1
# 7.290000e+09    1
# 7.200000e+09    1
# 5.500000e+09    1
# Name: count, Length: 465, dtype: int64

# %%
print(df[' City '].value_counts())
# Out:
#  City
# New York          43
# Houston           24
# Chicago           14
# Atlanta           13
# Dallas             9
#                   ..
# Downers Grove      1
# New Braunfels      1
# Livonia            1
# Westchester        1
# Herndon            1
# Name: count, Length: 226, dtype: int64

# %%
df.rename(columns={'City':'City'},inplace=True)
df['State'].value_counts()
# Out:
# State
# California              58
# Texas                   54
# New York                53
# Illinois                32
# Ohio                    28
# Virginia                25
# Florida                 22
# Pennsylvania            19
# Minnesota               17
# Georgia                 17
# Massachusetts           16
# Connecticut             15
# Michigan                15
# New Jersey              15
# Washington              11
# North Carolina          11
# Tennessee               11
# Arizona                  9
# Indiana                  8
# Missouri                 8
# Wisconsin                8
# Colorado                 8
# Rhode Island             5
# Arkansas                 4
# Nebraska                 4
# District Of Columbia     3
# Kentucky                 3
# Maryland                 3
# Oklahoma                 3
# Nevada                   3
# Idaho                    2
# Oregon                   2
# Iowa                     2
# Louisiana                2
# Alabama                  2
# Delaware                 1
# Kansas                   1
# Name: count, dtype: int64

# %%
print(df.columns)
# Out:
# Index(['Rank', 'Company', 'Industry', 'Revenue ($)', ' City ', 'State', 'Zip',
#        'Website', 'Employees', 'CEO'],
#       dtype='str')

# %%
print(df['Zip'].value_counts())
# Out:
# Zip
# 77002    11
# 75039     7
# 10036     7
# 10001     6
# 95054     5
#          ..
# 48152     1
# 43287     1
# 33133     1
# 60154     1
# 20170     1
# Name: count, Length: 368, dtype: int64

# %%
df['Website'].value_counts()
# Out:
# Website
# amazon.com               1
# walmart.com              1
# unitedhealthgroup.com    1
# apple.com                1
# abc.xyz                  1
#                         ..
# ea.com                   1
# newellbrands.com         1
# ingredion.com            1
# key.com                  1
# qxo.com                  1
# Name: count, Length: 500, dtype: int64

# %%
df['Employees'].value_counts()
# Out:
# Employees
# 24,000    8
# 48,000    7
# 34,000    5
# 22,000    5
# 44,000    4
#          ..
# 17,287    1
# 7,258     1
# 11,200    1
# 16,753    1
# 8,068     1
# Name: count, Length: 415, dtype: int64

# %%
df['Employees'] = df['Employees'].str.replace(',','').astype(int)

# %%
print(df['Employees'].dtype)
# Out:
# int64

# %%
df['Employees'].value_counts()
# Out:
# Employees
# 24000    8
# 48000    7
# 34000    5
# 22000    5
# 44000    4
#         ..
# 17287    1
# 7258     1
# 11200    1
# 16753    1
# 8068     1
# Name: count, Length: 415, dtype: int64

# %%
df['CEO'].value_counts()
# Out:
# CEO
# Kevin Murphy            2
# Andrew Jassy            1
# John Furner             1
# Stephen Hemsley         1
# Timothy Cook            1
#                        ..
# Andrew Wilson           1
# Christopher Peterson    1
# James Zallie            1
# Christopher Gorman      1
# Julian Francis          1
# Name: count, Length: 499, dtype: int64

# %%
industry_summary = df.groupby('Industry').agg({
    'Revenue ($)':'sum',
    'Employees':'sum'
}).sort_values(by='Revenue ($)',ascending=False)
print('\n Top Industries by Revenue and Employees')
print(industry_summary.head(10))
# Out:
#  Top Industries by Revenue and Employees
#                                            Revenue ($)  Employees
# Industry
# Internet Services and Retailing           1.502510e+12    2071753
# General Merchandisers                     1.167300e+12    3101189
# Health Care: Insurance and Managed Care   9.905900e+11     650259
# Petroleum Refining                        9.776080e+11     160534
# Wholesalers: Health Care                  9.664400e+11     188611
# Insurance: Property and Casualty (Stock)  8.678020e+11     789207
# Commercial Banks                          7.413200e+11    1577003
# Health Care: Pharmacy and Other Services  7.240000e+11     572848
# Computers, Office Equipment               6.410310e+11     447684
# Diversified Financials                    6.225820e+11     350121

# %%
state_summary = df.groupby('State').agg({
    'Revenue ($)':'sum',
    'Employees':'sum'
}).sort_values(by='Revenue ($)',ascending=False)
print('\nTop States by Revenue and Employees')
print(state_summary.head(10))
# Out:
# Top States by Revenue and Employees
#                Revenue ($)  Employees
# State
# Texas         2.731988e+12    2432908
# California    2.604980e+12    2857773
# New York      1.775676e+12    2825511
# Washington    1.451024e+12    2750591
# Ohio          1.050045e+12    1255122
# Illinois      1.038272e+12    1655409
# Minnesota     8.329220e+11    1269765
# Arkansas      7.962000e+11    2283196
# Virginia      7.300820e+11    1461153
# Pennsylvania  6.897970e+11     929141

# %%
# Pivot table
pivot_table_industry_state = pd.pivot_table(df,values=['Revenue ($)','Employees'],index='Industry',columns='State',aggfunc='mean')
print('Average Revenue and Employees by Industry and State:')
print(pivot_table_industry_state.head(10))
# Out:
# Average Revenue and Employees by Industry and State:
#                                Employees                               \
# State                            Alabama  Arizona Arkansas California
# Industry
# Advertising, Marketing               NaN      NaN      NaN        NaN
# Aerospace & Defense                  NaN      NaN      NaN        NaN
# Airlines                             NaN      NaN      NaN        NaN
# Apparel                              NaN      NaN      NaN    15100.0
# Automotive Retailing, Services       NaN  17400.0      NaN        NaN
# Beverages                            NaN      NaN      NaN     6043.0
# Building Materials, Glass        11971.0      NaN      NaN        NaN
# Chemicals                            NaN      NaN      NaN        NaN
# Commercial Banks                 19644.0      NaN      NaN   217502.0
# Computer Software                    NaN      NaN      NaN    35627.4
#
#                                                               \
# State                          Colorado Connecticut Delaware
# Industry
# Advertising, Marketing              NaN         NaN      NaN
# Aerospace & Defense                 NaN         NaN      NaN
# Airlines                            NaN         NaN      NaN
# Apparel                         24000.0         NaN      NaN
# Automotive Retailing, Services      NaN         NaN      NaN
# Beverages                           NaN         NaN      NaN
# Building Materials, Glass           NaN         NaN      NaN
# Chemicals                           NaN         NaN  24000.0
# Commercial Banks                    NaN         NaN      NaN
# Computer Software                   NaN         NaN      NaN
#
#                                                                         ...  \
# State                          District Of Columbia  Florida   Georgia  ...
# Industry                                                                ...
# Advertising, Marketing                          NaN      NaN       NaN  ...
# Aerospace & Defense                             NaN  47000.0       NaN  ...
# Airlines                                        NaN      NaN  103000.0  ...
# Apparel                                         NaN      NaN       NaN  ...
# Automotive Retailing, Services                  NaN  25550.0   15000.0  ...
# Beverages                                       NaN      NaN   69700.0  ...
# Building Materials, Glass                       NaN      NaN       NaN  ...
# Chemicals                                       NaN  13765.0       NaN  ...
# Commercial Banks                                NaN      NaN       NaN  ...
# Computer Software                               NaN      NaN       NaN  ...
#
#                                  Revenue ($)                         \
# State                                   Ohio Oklahoma        Oregon
# Industry
# Advertising, Marketing                   NaN      NaN           NaN
# Aerospace & Defense             2.639000e+10      NaN           NaN
# Airlines                                 NaN      NaN           NaN
# Apparel                                  NaN      NaN  4.644000e+10
# Automotive Retailing, Services           NaN      NaN  3.761000e+10
# Beverages                                NaN      NaN           NaN
# Building Materials, Glass       1.166000e+10      NaN           NaN
# Chemicals                       2.328000e+10      NaN           NaN
# Commercial Banks                7.610000e+09      NaN           NaN
# Computer Software                        NaN      NaN           NaN
#
#                                                                           \
# State                           Pennsylvania  Rhode Island     Tennessee
# Industry
# Advertising, Marketing                   NaN           NaN           NaN
# Aerospace & Defense             7.980000e+09  1.424000e+10           NaN
# Airlines                                 NaN           NaN           NaN
# Apparel                                  NaN           NaN           NaN
# Automotive Retailing, Services           NaN           NaN           NaN
# Beverages                                NaN           NaN           NaN
# Building Materials, Glass                NaN           NaN           NaN
# Chemicals                       1.386500e+10           NaN  9.020000e+09
# Commercial Banks                2.180000e+10  7.440000e+09           NaN
# Computer Software                        NaN           NaN           NaN
#
#                                                                           \
# State                                  Texas      Virginia    Washington
# Industry
# Advertising, Marketing                   NaN           NaN           NaN
# Aerospace & Defense                      NaN  5.424000e+10           NaN
# Airlines                        4.092000e+10           NaN  1.414000e+10
# Apparel                                  NaN           NaN           NaN
# Automotive Retailing, Services  1.510500e+10  2.828000e+10           NaN
# Beverages                                NaN           NaN           NaN
# Building Materials, Glass       1.565000e+10           NaN           NaN
# Chemicals                       1.059500e+10           NaN           NaN
# Commercial Banks                         NaN  2.889000e+10           NaN
# Computer Software               6.102000e+10           NaN  2.938100e+11
#
#
# State                          Wisconsin
# Industry
# Advertising, Marketing               NaN
# Aerospace & Defense                  NaN
# Airlines                             NaN
# Apparel                              NaN
# Automotive Retailing, Services       NaN
# Beverages                            NaN
# Building Materials, Glass            NaN
# Chemicals                            NaN
# Commercial Banks                     NaN
# Computer Software                    NaN
#
# [10 rows x 74 columns]

# %%
pivot_table_state_industry = pd.pivot_table(df,values=['Revenue ($)','Employees'],index='State',columns='Industry',aggfunc='mean')
print('Average Revenue and Employees by State and Industry')
print(pivot_table_state_industry.head())
# Out:
# Average Revenue and Employees by State and Industry
#                         Employees                                        \
# Industry   Advertising, Marketing Aerospace & Defense Airlines  Apparel
# State
# Alabama                       NaN                 NaN      NaN      NaN
# Arizona                       NaN                 NaN      NaN      NaN
# Arkansas                      NaN                 NaN      NaN      NaN
# California                    NaN                 NaN      NaN  15100.0
# Colorado                      NaN                 NaN      NaN  24000.0
#
#                                                                                \
# Industry   Automotive Retailing, Services Beverages Building Materials, Glass
# State
# Alabama                               NaN       NaN                   11971.0
# Arizona                           17400.0       NaN                       NaN
# Arkansas                              NaN       NaN                       NaN
# California                            NaN    6043.0                       NaN
# Colorado                              NaN       NaN                       NaN
#
#                                                          ...  \
# Industry   Chemicals Commercial Banks Computer Software  ...
# State                                                    ...
# Alabama          NaN          19644.0               NaN  ...
# Arizona          NaN              NaN               NaN  ...
# Arkansas         NaN              NaN               NaN  ...
# California       NaN         217502.0           35627.4  ...
# Colorado         NaN              NaN               NaN  ...
#
#                   Revenue ($)                                       \
# Industry   Telecommunications Tobacco Transportation and Logistics
# State
# Alabama                   NaN     NaN                          NaN
# Arizona                   NaN     NaN                          NaN
# Arkansas                  NaN     NaN                          NaN
# California                NaN     NaN                          NaN
# Colorado         1.518000e+10     NaN                          NaN
#
#                                                                 \
# Industry   Trucking, Truck Leasing Utilities: Gas and Electric
# State
# Alabama                        NaN                         NaN
# Arizona                        NaN                         NaN
# Arkansas              1.205000e+10                         NaN
# California                     NaN                1.885333e+10
# Colorado                       NaN                         NaN
#
#                                                       \
# Industry   Waste Management Wholesalers: Diversified
# State
# Alabama                 NaN                      NaN
# Arizona        1.650000e+10                      NaN
# Arkansas                NaN                      NaN
# California              NaN             1.050000e+10
# Colorado                NaN                      NaN
#
#                                                           \
# Industry   Wholesalers: Electronics and Office Equipment
# State
# Alabama                                              NaN
# Arizona                                     2.250000e+10
# Arkansas                                             NaN
# California                                  5.599500e+10
# Colorado                                    2.939000e+10
#
#
# Industry   Wholesalers: Food and Grocery Wholesalers: Health Care
# State
# Alabama                              NaN                      NaN
# Arizona                              NaN                      NaN
# Arkansas                             NaN                      NaN
# California                           NaN                      NaN
# Colorado                             NaN                      NaN
#
# [5 rows x 134 columns]

# %%
crosstab_industry_state = pd.crosstab(index=df['Industry'],columns=df['State'])
print('Crosstab of Industry by State (Number of companies):')
print(crosstab_industry_state.head())
# Out:
# Crosstab of Industry by State (Number of companies):
# State                           Alabama  Arizona  Arkansas  California  \
# Industry
# Advertising, Marketing                0        0         0           0
# Aerospace & Defense                   0        0         0           0
# Airlines                              0        0         0           0
# Apparel                               0        0         0           1
# Automotive Retailing, Services        0        1         0           0
#
# State                           Colorado  Connecticut  Delaware  \
# Industry
# Advertising, Marketing                 0            0         0
# Aerospace & Defense                    0            0         0
# Airlines                               0            0         0
# Apparel                                1            0         0
# Automotive Retailing, Services         0            0         0
#
# State                           District Of Columbia  Florida  Georgia  ...  \
# Industry                                                                ...
# Advertising, Marketing                             0        0        0  ...
# Aerospace & Defense                                0        1        0  ...
# Airlines                                           0        0        1  ...
# Apparel                                            0        0        0  ...
# Automotive Retailing, Services                     0        2        1  ...
#
# State                           Ohio  Oklahoma  Oregon  Pennsylvania  \
# Industry
# Advertising, Marketing             0         0       0             0
# Aerospace & Defense                2         0       0             1
# Airlines                           0         0       0             0
# Apparel                            0         0       1             0
# Automotive Retailing, Services     0         0       1             0
#
# State                           Rhode Island  Tennessee  Texas  Virginia  \
# Industry
# Advertising, Marketing                     0          0      0         0
# Aerospace & Defense                        1          0      0         5
# Airlines                                   0          0      2         0
# Apparel                                    0          0      0         0
# Automotive Retailing, Services             0          0      2         1
#
# State                           Washington  Wisconsin
# Industry
# Advertising, Marketing                   0          0
# Aerospace & Defense                      0          0
# Airlines                                 1          0
# Apparel                                  0          0
# Automotive Retailing, Services           0          0
#
# [5 rows x 37 columns]

# %%
crosstab_industry_ceo = pd.crosstab(index=df['Industry'],columns=df['CEO'])
print('\nCrosstab of Industry by CEO(Number of Companies):')
print(crosstab_industry_ceo.head(1))
# Out:
# Crosstab of Industry by CEO(Number of Companies):
# CEO                     Adaire Fox-Martin  Adam Norwitt  Adam Schechter  \
# Industry
# Advertising, Marketing                  0             0               0
#
# CEO                     Alan Armstrong  Alan Schnitzer  Albert Bourla  \
# Industry
# Advertising, Marketing               0               0              0
#
# CEO                     Albert Nahmad  Alex Chriss  Andrew Clyde  \
# Industry
# Advertising, Marketing              0            0             0
#
# CEO                     Andrew Jassy  ...  William Hornbuckle  \
# Industry                              ...
# Advertising, Marketing             0  ...                   0
#
# CEO                     William Krueger  William McDermott  \
# Industry
# Advertising, Marketing                0                  0
#
# CEO                     William Monteleone  William Nash  William Newlands  \
# Industry
# Advertising, Marketing                   0             0                 0
#
# CEO                     William Oplinger  William Rogers Jr.  \
# Industry
# Advertising, Marketing                 0                   0
#
# CEO                     William Stengel II  William Westrate
# Industry
# Advertising, Marketing                   0                 0
#
# [1 rows x 499 columns]

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='Employees',y='Revenue ($)',data=df,hue='Industry',size='Revenue ($)',sizes=(20,1000),alpha=0.7)
plt.title('Revenue Vs Employees by Industry')
plt.xlabel('Number of Employees')
plt.ylabel('Revenue ($)')
plt.xscale('log')
plt.yscale('log')
plt.grid(True,which='both',ls='--',c='0.7')
plt.legend(bbox_to_anchor=(1.05,1),loc='upper left',borderaxespad=0.,fontsize='small')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='Rank',y='Revenue ($)',data=df,hue='Industry',size='Employees',sizes=(20,1000),alpha=0.7)
plt.title('Rank Vs Revenue by Industry (Point size by Employees)')
plt.xlabel('Company Rank')
plt.ylabel('Revenue ($)')
plt.yscale('log')
plt.grid(True,which='both',ls='--',c='0.7')
plt.legend(bbox_to_anchor=(1.05,1),loc='upper left',borderaxespad=0,fontsize='small')
plt.tight_layout()
plt.show()

# %%
top_5_industries = industry_summary.head(5).index
filtered_data = df[df['Industry'].isin(top_5_industries)]

plt.figure(figsize=(15,10))
g = sns.FacetGrid(filtered_data,col='Industry',col_wrap=3,sharex=False,sharey=False)
g.map(sns.histplot,'Revenue ($)',bins=20,kde=True)
g.set_titles('Industry:{col_name}')
g.set_axis_labels('Revenue ($)')


for ax in g.axes.flat:
    ax.set_xscale('log')

plt.suptitle('Revenue Distribution Across Top 5 Industries (Histograms)', y=1.02) # Adjust suptitle position
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=industry_summary.head(10).index,y=industry_summary['Revenue ($)'].head(10),palette='viridis')
plt.title('Top 10 Industries by Revenue ($)')
plt.xlabel('Industry')
plt.ylabel('Total Revenue ($)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=state_summary.head(10).index,y=state_summary['Revenue ($)'].head(10),palette='magma')
plt.title('Top 10 states by revenue')
plt.xlabel('State')
plt.ylabel('Total Revenue')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=industry_summary.sort_values(by='Employees',ascending=False).head(10).index,y=industry_summary.sort_values(by='Employees',ascending=False)['Employees'].head(10),palette='viridis')

plt.title('Top 10 Industries by Employee count')
plt.xlabel('Industry')
plt.ylabel('Total Employees')
plt.xticks(rotation=45,ha='right')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=state_summary.sort_values(by='Employees',ascending=False).head(10).index,y=state_summary.sort_values(by='Employees',ascending=False)['Employees'].head(10),palette='plasma')
plt.title('Top 10 States by Employee count')
plt.xlabel('State')
plt.ylabel('Total Employees')
plt.xticks(rotation=45,ha='right')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14,8))
top_industries = industry_summary.head(10).index
sns.boxplot(x='Industry',y='Revenue ($)',data=df[df['Industry'].isin(top_industries)],palette='viridis')
plt.title('Distribution of Revenue ($) for Top Industries')
plt.xlabel('Industry')
plt.ylabel('Revenue ($)')
plt.xticks(rotation=45,ha='right')
plt.yscale('log')
plt.tight_layout()
plt.show()

# %%
top_10_industries = industry_summary.head(10).index
top_10_states = state_summary.head(10).index

revenue_plot = pivot_table_industry_state['Revenue ($)'].loc[top_10_industries,top_10_states]

plt.figure(figsize=(14,10))
sns.heatmap(revenue_plot,annot=True,fmt='.1E',cmap="YlGnBu", linewidths=.5)
plt.title('Average Revenue ($) by Top 10 Industries and Top 10 States')
plt.xlabel('State')
plt.ylabel('Industry')
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 8))
top_industries_revenue = industry_summary['Revenue ($)'].head(5)
other_industries_revenue = industry_summary['Revenue ($)'].iloc[5:].sum()
pie_data_industry = pd.concat([top_industries_revenue, pd.Series(other_industries_revenue, index=['Other'])])
plt.pie(pie_data_industry, labels=pie_data_industry.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('viridis'))
plt.title('Revenue Distribution by Top 5 Industries')
plt.axis('equal')
plt.show()

# %%
plt.figure(figsize=(10, 8))
top_states_revenue = state_summary['Revenue ($)'].head(5)
other_states_revenue = state_summary['Revenue ($)'].iloc[5:].sum()
pie_data_state = pd.concat([top_states_revenue, pd.Series(other_states_revenue, index=['Other'])])
plt.pie(pie_data_state, labels=pie_data_state.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('magma'))
plt.title('Revenue Distribution by Top 5 States')
plt.axis('equal')
plt.show()
